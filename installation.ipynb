# %%
# !pip install labelme tensorflow  opencv-python matplotlib albumentations
# Out:
# ...
#   Using cached labelme-5.4.1-py3-none-any.whl
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/d1/2c/285651e5dbdbd197234c9d000af710f128bce6f851213ec503e399b8f6c0/opencv_python-4.10.0.82-cp37-abi3-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/f4/b4/c1700c8b2ff8d379c187f37055e61bd7a611eb2c544466600a7734793d54/matplotlib-3.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached matplotlib-3.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Obtaining dependency information for albumentations from https://files.pythonhosted.org/packages/cf/7a/e0d953f512e4ee92a70f8ddaa83a0fa48085d03ce5c8ccda11e1d5139235/albumentations-1.4.8-py3-none-any.whl.metadata
# ...

# %%
# !pip install customtkinter
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.6 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
#go to img_processing
